# %%
import pandas as pd

df = pd.read_csv("Uniform-SPUR.csv") # pd.read_csv("Uniform-KUS.csv")
df
# Out:
#                                                  file      time  \
# 0   /home/samplingfm/Benchmarks/Blasted_Real/blast...  2372.200
# 1   /home/samplingfm/Benchmarks/Blasted_Real/blast...  1921.070
# 2   /home/samplingfm/Benchmarks/Blasted_Real/blast...  1320.116
# 3   /home/samplingfm/Benchmarks/Blasted_Real/blast...  1214.608
# 4   /home/samplingfm/Benchmarks/Blasted_Real/blast...  3600.106
# 5   /home/samplingfm/Benchmarks/Blasted_Real/blast...   865.126
# 6   /home/samplingfm/Benchmarks/Blasted_Real/blast...  3577.189
# 7   /home/samplingfm/Benchmarks/Blasted_Real/blast...  2710.432
# 8   /home/samplingfm/Benchmarks/Blasted_Real/blast...  1650.422
# 9   /home/samplingfm/Benchmarks/Blasted_Real/blast...  2472.875
# 10  /home/samplingfm/Benchmarks/Blasted_Real/blast...  3600.106
# 11  /home/samplingfm/Benchmarks/Blasted_Real/blast...  3600.018
# 12  /home/samplingfm/Benchmarks/Blasted_Real/blast...  2319.065
# 13  /home/samplingfm/Benchmarks/Blasted_Real/blast...     0.855
# 14  /home/samplingfm/Benchmarks/Blasted_Real/blast...  1213.203
# 15  /home/samplingfm/Benchmarks/Blasted_Real/blast...  3600.029
# 16  /home/samplingfm/Benchmarks/Blasted_Real/blast...   308.916
# 17  /home/samplingfm/Benchmarks/Blasted_Real/blast...  3600.105
# 18  /home/samplingfm/Benchmarks/Blasted_Real/blast...  1524.181
# 19  /home/samplingfm/Benchmarks/Blasted_Real/blast...  1027.575
#
#                                            cmd_output err_output Uniform  \
# 0   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 1   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 2   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 3   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 4                                                 NaN        NaN     NaN
# 5   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 6   b'Experiment: 0     of     1\nconstantFactor:3...        b''   False
# 7   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 8   b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 9   b'ZH - Rehash the table.\nts 2097152 2097151\n...        b''   False
# 10                                                NaN        NaN     NaN
# 11                                                NaN        NaN     NaN
# 12  b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 13  b'Experiment: 0     of     1\nconstantFactor:3...        b''   False
# 14  b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 15                                                NaN        NaN     NaN
# 16  b'Experiment: 0     of     1\nconstantFactor:3...        b''   False
# 17                                                NaN        NaN     NaN
# 18  b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
# 19  b'Experiment: 0     of     1\nconstantFactor:3...        b''    True
#
#     Timeout
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False

# %%
# find output/ -type f -name "*.csv" -newermt 2020-09-17 -not -path "*/.virtfs_metadata/*" | xargs wc -l
import os
import pandas as pd
from stat import S_ISREG, ST_CTIME, ST_MODE
import time
from datetime import datetime
 
dfs = []
rootDir = 'output2'
for dirName, subdirList, fileList in os.walk(rootDir, topdown=False):
    if ".virtfs_metadata" in dirName:
        continue
    for fname in fileList:
        # print('%s\t%s' % (dirName, fname))
        stat_file = os.stat(os.path.join(dirName, fname))
        cdate = stat_file[ST_CTIME]
        creationtime_file = time.ctime(os.path.getmtime(os.path.join(dirName, fname)))
        creationdate_file = datetime.fromtimestamp(os.path.getmtime(os.path.join(dirName, fname))).date()
        targeted_date = datetime.strptime("2020-09-16", "%Y-%m-%d")
        # if creationdate_file.day != targeted_date.day:
        #    continue
        if fname.endswith(".csv"):
            df = pd.read_csv(os.path.join(dirName, fname))
            df['sampler'] = fname
            dfs.append(df)

# for df in dfs:
    # df['sampler'] = solver
#    if len(df['file']) == 1 and "FM-3" in df['file'][0]:
#        print(solver)
#        print(df['file'])
#        print(df['Uniform'].value_counts(dropna=False))
#        print()


all_results = pd.concat(dfs)

all_results.to_csv('all-results-sampler.csv')
all_results[['file', 'time', 'Uniform', 'Timeout', 'sampler']].to_csv('all-results-sampler-digest.csv')

# %%
all_results.drop_duplicates(subset=['file', 'sampler', 'Uniform', 'Timeout'], inplace=True)
# all_results.query("sampler == 'Uniform-DistanceBasedSampling.csv'")

i = 0
df_summary = pd.DataFrame(columns=['sampler', "nbench", "nTrueUniform", "nFalseUniform", "nNAUniform"])
for s in all_results["sampler"].unique():
    nbench = len(all_results.query("sampler == '" + s + "'"))
    ntrueu = len(all_results.query("Uniform == True and sampler == '" + s + "'"))
    nfalseu = len(all_results.query("Uniform == False and sampler == '" + s + "'"))
    nnau = len(all_results.query("Uniform != True and Uniform != False and sampler == '" + s + "'"))
    print(s, nbench, ntrueu)
    df_summary.loc[i] = (s, nbench, ntrueu, nfalseu, nnau)
    i = i + 1

df_summary.to_csv('summary-uniformity-samplers.csv')
df_summary
#all_results.query("sampler == 'Uniform-SPUR.csv' and Uniform == False")
# Out:
# Uniform-SPUR.csv 57 26
# Uniform-CustomSampler.csv 32 21
# Uniform-DistanceBasedSampling.csv 140 0
# Uniform-SMARCH.csv 213 0
# Uniform-UniGen.csv 12 0
# Uniform-STS.csv 234 0
# Uniform-UNIGEN2.csv 13 1
# Uniform-QuickSampler.csv 257 0
# Uniform-KUS.csv 37 19
# Uniform-UniGen3.csv 18 9
#                              sampler nbench nTrueUniform nFalseUniform  \
# 0                   Uniform-SPUR.csv     57           26            11
# 1          Uniform-CustomSampler.csv     32           21             5
# 2  Uniform-DistanceBasedSampling.csv    140            0           132
# 3                 Uniform-SMARCH.csv    213            0           168
# 4                 Uniform-UniGen.csv     12            0             0
# 5                    Uniform-STS.csv    234            0            99
# 6                Uniform-UNIGEN2.csv     13            1             2
# 7           Uniform-QuickSampler.csv    257            0           239
# 8                    Uniform-KUS.csv     37           19             6
# 9                Uniform-UniGen3.csv     18            9             4
#
#   nNAUniform
# 0         20
# 1          6
# 2          8
# 3         45
# 4         12
# 5        135
# 6         10
# 7         18
# 8         12
# 9          5
